# %%
# For data
import networkx as nx
from parse import *
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from IPython.core.display import display, HTML
from IPython.display import Javascript
from string import Template
import json

# %%
import os
import pandas as pd

# %% [raw]
# random.seed(3)

# %%
files = []
f = os.listdir('gml_topo/')
for file in f:
    if '.gml' in file:
        files.append(file)
files
# Out:
# ['Bandcon.gml',
#  'Garr201105.gml',
#  'VtlWavenet2011.gml',
#  'Belnet2010.gml',
#  'Shentel.gml',
#  'Easynet.gml',
#  'Arpanet19719.gml',
#  'Padi.gml',
#  'Cudi.gml',
#  'KentmanApr2007.gml',
#  'Cernet.gml',
#  'Cogentco.gml',
#  'Garr199905.gml',
#  'LambdaNet.gml',
#  'GtsRomania.gml',
#  'Airtel.gml',
#  'Navigata.gml',
#  'Geant2010.gml',
#  'Renam.gml',
#  'Marwan.gml',
#  'Chinanet.gml',
#  'Zamren.gml',
#  'Twaren.gml',
#  'Integra.gml',
#  'Cesnet1999.gml',
#  'CrlNetworkServices.gml',
#  'Garr200109.gml',
#  'Cesnet200304.gml',
#  'Nordu2010.gml',
#  'Esnet.gml',
#  'Compuserve.gml',
#  'Rhnet.gml',
#  'Garr201008.gml',
#  'Getnet.gml',
#  'Garr200212.gml',
#  'DeutscheTelekom.gml',
#  'Ernet.gml',
#  'Kreonet.gml',
#  'Garr201005.gml',
#  'HiberniaUs.gml',
#  'KentmanFeb2008.gml',
#  'Istar.gml',
#  'Azrena.gml',
#  'Cesnet201006.gml',
#  'Ulaknet.gml',
#  'KentmanJan2011.gml',
#  'Arn.gml',
#  'Ai3.gml',
#  'BtLatinAmerica.gml',
#  'Vinaren.gml',
#  'Switch.gml',
#  'Pern.gml',
#  'Abilene.gml',
#  'GtsHungary.gml',
#  'Renater2010.gml',
#  'Harnet.gml',
#  'Garr201112.gml',
#  'Kdl.gml',
#  'Garr201109.gml',
#  'Garr201111.gml',
#  'Nordu1997.gml',
#  'PionierL3.gml',
#  'Grnet.gml',
#  'Ntelos.gml',
#  'Claranet.gml',
#  'Packetexchange.gml',
#  'Reuna.gml',
#  'Renater2008.gml',
#  'GtsSlovakia.gml',
#  'Janetlense.gml',
#  'Globenet.gml',
#  'Garr201103.gml',
#  'Xspedius.gml',
#  'Ibm.gml',
#  'BtEurope.gml',
#  'Ion.gml',
#  'Tinet.gml',
#  'Latnet.gml',
#  'Renater2001.gml',
#  'Garr201110.gml',
#  'Garr201007.gml',
#  'Bellcanada.gml',
#  'Agis.gml',
#  'IowaStatewideFiberMap.gml',
#  'Garr200404.gml',
#  'Oxford.gml',
#  'Belnet2004.gml',
#  'Itnet.gml',
#  'Garr201201.gml',
#  'Intellifiber.gml',
#  'Jgn2Plus.gml',
#  'Cynet.gml',
#  'UniC.gml',
#  'Aarnet.gml',
#  'Eenet.gml',
#  'Sprint.gml',
#  'Sunet.gml',
#  'Sanren.gml',
#  'Bren.gml',
#  'Atmnet.gml',
#  'Roedunet.gml',
#  'Geant2001.gml',
#  'Ilan.gml',
#  'Epoch.gml',
#  'SwitchL3.gml',
#  'Digex.gml',
#  'Garr201004.gml',
#  'Garr201012.gml',
#  'Karen.gml',
#  'Iinet.gml',
#  'BtNorthAmerica.gml',
#  'Telecomserbia.gml',
#  'Heanet.gml',
#  'Niif.gml',
#  'Renater1999.gml',
#  'TataNld.gml',
#  'Sinet.gml',
#  'Cesnet200511.gml',
#  'UsSignal.gml',
#  'Garr199901.gml',
#  'Gblnet.gml',
#  'Myren.gml',
#  'Geant2009.gml',
#  'Xeex.gml',
#  'York.gml',
#  'Garr200908.gml',
#  'Interoute.gml',
#  'Litnet.gml',
#  'Syringa.gml',
#  'DialtelecomCz.gml',
#  'Cesnet2001.gml',
#  'HurricaneElectric.gml',
#  'Eunetworks.gml',
#  'Garr199904.gml',
#  'Abvt.gml',
#  'Nsfcnet.gml',
#  'Garr200909.gml',
#  'KentmanJul2005.gml',
#  'Belnet2006.gml',
#  'HiberniaUk.gml',
#  'Arpanet19723.gml',
#  'KentmanAug2005.gml',
#  'Telcove.gml',
#  'Bics.gml',
#  'RoedunetFibre.gml',
#  'Iij.gml',
#  'Belnet2009.gml',
#  'Palmetto.gml',
#  'Carnet.gml',
#  'RedBestel.gml',
#  'Gridnet.gml',
#  'Garr201010.gml',
#  'Uran.gml',
#  'GtsCzechRepublic.gml',
#  'HostwayInternational.gml',
#  'Missouri.gml',
#  'Biznet.gml',
#  'VtlWavenet2008.gml',
#  'Janetbackbone.gml',
#  'PionierL1.gml',
#  'Garr200902.gml',
#  'Funet.gml',
#  'Layer42.gml',
#  'BsonetEurope.gml',
#  'Belnet2007.gml',
#  'Garr201003.gml',
#  'Surfnet.gml',
#  'AttMpls.gml',
#  'Garr201107.gml',
#  'Gambia.gml',
#  'Rnp.gml',
#  'Noel.gml',
#  'Psinet.gml',
#  'Internode.gml',
#  'Savvis.gml',
#  'Columbus.gml',
#  'Arpanet19706.gml',
#  'Fatman.gml',
#  'Fccn.gml',
#  'Marnet.gml',
#  'Renater2004.gml',
#  'Nordu1989.gml',
#  'Garr200112.gml',
#  'Internetmci.gml',
#  'Renater2006.gml',
#  'Bbnplanet.gml',
#  'AsnetAm.gml',
#  'Arpanet196912.gml',
#  'Sanet.gml',
#  'Cesnet1993.gml',
#  'Evolink.gml',
#  'Darkstrand.gml',
#  'Singaren.gml',
#  'Garr200912.gml',
#  'Aconet.gml',
#  'Uninet.gml',
#  'JanetExternal.gml',
#  'Garr201104.gml',
#  'Geant2012.gml',
#  'Arnes.gml',
#  'Colt.gml',
#  'UsCarrier.gml',
#  'Grena.gml',
#  'Ntt.gml',
#  'GtsCe.gml',
#  'Arpanet19728.gml',
#  'Amres.gml',
#  'Uninett2011.gml',
#  'Cwix.gml',
#  'Cesnet200603.gml',
#  'Tw.gml',
#  'BtAsiaPac.gml',
#  'Dataxchange.gml',
#  'Uninett2010.gml',
#  'Oteglobe.gml',
#  'Sago.gml',
#  'TLex.gml',
#  'Uunet.gml',
#  'Basnet.gml',
#  'Peer1.gml',
#  'NetworkUsa.gml',
#  'Garr201101.gml',
#  'HiberniaCanada.gml',
#  'Restena.gml',
#  'Garr201102.gml',
#  'Globalcenter.gml',
#  'Pacificwave.gml',
#  'GtsPoland.gml',
#  'Belnet2003.gml',
#  'Bellsouth.gml',
#  'Nextgen.gml',
#  'Goodnet.gml',
#  'Dfn.gml',
#  'HiberniaGlobal.gml',
#  'VisionNet.gml',
#  'Belnet2008.gml',
#  'Deltacom.gml',
#  'Rediris.gml',
#  'WideJpn.gml',
#  'Garr201001.gml',
#  'Highwinds.gml',
#  'Cesnet1997.gml',
#  'EliBackbone.gml',
#  'Iris.gml',
#  'Garr201108.gml',
#  'HiberniaNireland.gml',
#  'BeyondTheNetwork.gml',
#  'Quest.gml',
#  'Belnet2005.gml',
#  'Intranetwork.gml',
#  'Nordu2005.gml',
#  'Nsfnet.gml',
#  'Cesnet200706.gml',
#  'Spiralight.gml',
#  'Napnet.gml',
#  'Ans.gml',
#  'HiberniaIreland.gml',
#  'Forthnet.gml',
#  'Netrail.gml',
#  'Mren.gml',
#  'Canerie.gml']

# %%
data = []
for file in files:
    print(file)
    H = nx.read_graphml('gml_topo/' + file.replace('.gml', '.graphml'))
    data.append([file, len(H.nodes()), len(H.edges())])
#     print(data)
# Out:
# Bandcon.gml
# Garr201105.gml
# VtlWavenet2011.gml
# Belnet2010.gml
# Shentel.gml
# Easynet.gml
# Arpanet19719.gml
# Padi.gml
# Cudi.gml
# KentmanApr2007.gml
# Cernet.gml
# Cogentco.gml
# Garr199905.gml
# LambdaNet.gml
# GtsRomania.gml
# Airtel.gml
# Navigata.gml
# Geant2010.gml
# Renam.gml
# Marwan.gml
# Chinanet.gml
# Zamren.gml
# Twaren.gml
# Integra.gml
# Cesnet1999.gml
# CrlNetworkServices.gml
# Garr200109.gml
# Cesnet200304.gml
# Nordu2010.gml
# Esnet.gml
# Compuserve.gml
# Rhnet.gml
# Garr201008.gml
# Getnet.gml
# Garr200212.gml
# DeutscheTelekom.gml
# Ernet.gml
# Kreonet.gml
# Garr201005.gml
# HiberniaUs.gml
# KentmanFeb2008.gml
# Istar.gml
# Azrena.gml
# Cesnet201006.gml
# Ulaknet.gml
# KentmanJan2011.gml
# Arn.gml
# Ai3.gml
# BtLatinAmerica.gml
# Vinaren.gml
# Switch.gml
# Pern.gml
# Abilene.gml
# GtsHungary.gml
# Renater2010.gml
# Harnet.gml
# Garr201112.gml
# Kdl.gml
# Garr201109.gml
# Garr201111.gml
# Nordu1997.gml
# PionierL3.gml
# Grnet.gml
# Ntelos.gml
# Claranet.gml
# Packetexchange.gml
# Reuna.gml
# Renater2008.gml
# GtsSlovakia.gml
# Janetlense.gml
# Globenet.gml
# Garr201103.gml
# Xspedius.gml
# Ibm.gml
# BtEurope.gml
# Ion.gml
# Tinet.gml
# Latnet.gml
# Renater2001.gml
# Garr201110.gml
# Garr201007.gml
# Bellcanada.gml
# Agis.gml
# IowaStatewideFiberMap.gml
# Garr200404.gml
# Oxford.gml
# Belnet2004.gml
# Itnet.gml
# Garr201201.gml
# Intellifiber.gml
# Jgn2Plus.gml
# Cynet.gml
# UniC.gml
# Aarnet.gml
# Eenet.gml
# Sprint.gml
# Sunet.gml
# Sanren.gml
# Bren.gml
# Atmnet.gml
# Roedunet.gml
# Geant2001.gml
# Ilan.gml
# Epoch.gml
# SwitchL3.gml
# Digex.gml
# Garr201004.gml
# Garr201012.gml
# Karen.gml
# Iinet.gml
# BtNorthAmerica.gml
# Telecomserbia.gml
# Heanet.gml
# Niif.gml
# Renater1999.gml
# TataNld.gml
# Sinet.gml
# Cesnet200511.gml
# UsSignal.gml
# Garr199901.gml
# Gblnet.gml
# Myren.gml
# Geant2009.gml
# Xeex.gml
# York.gml
# Garr200908.gml
# Interoute.gml
# Litnet.gml
# Syringa.gml
# DialtelecomCz.gml
# Cesnet2001.gml
# HurricaneElectric.gml
# Eunetworks.gml
# Garr199904.gml
# Abvt.gml
# Nsfcnet.gml
# Garr200909.gml
# KentmanJul2005.gml
# Belnet2006.gml
# HiberniaUk.gml
# Arpanet19723.gml
# KentmanAug2005.gml
# Telcove.gml
# Bics.gml
# RoedunetFibre.gml
# Iij.gml
# Belnet2009.gml
# Palmetto.gml
# Carnet.gml
# RedBestel.gml
# Gridnet.gml
# Garr201010.gml
# Uran.gml
# GtsCzechRepublic.gml
# HostwayInternational.gml
# Missouri.gml
# Biznet.gml
# VtlWavenet2008.gml
# Janetbackbone.gml
# PionierL1.gml
# Garr200902.gml
# Funet.gml
# Layer42.gml
# BsonetEurope.gml
# Belnet2007.gml
# Garr201003.gml
# Surfnet.gml
# AttMpls.gml
# Garr201107.gml
# Gambia.gml
# Rnp.gml
# Noel.gml
# Psinet.gml
# Internode.gml
# Savvis.gml
# Columbus.gml
# Arpanet19706.gml
# Fatman.gml
# Fccn.gml
# Marnet.gml
# Renater2004.gml
# Nordu1989.gml
# Garr200112.gml
# Internetmci.gml
# Renater2006.gml
# Bbnplanet.gml
# AsnetAm.gml
# Arpanet196912.gml
# Sanet.gml
# Cesnet1993.gml
# Evolink.gml
# Darkstrand.gml
# Singaren.gml
# Garr200912.gml
# Aconet.gml
# Uninet.gml
# JanetExternal.gml
# Garr201104.gml
# Geant2012.gml
# Arnes.gml
# Colt.gml
# UsCarrier.gml
# Grena.gml
# Ntt.gml
# GtsCe.gml
# Arpanet19728.gml
# Amres.gml
# Uninett2011.gml
# Cwix.gml
# Cesnet200603.gml
# Tw.gml
# BtAsiaPac.gml
# Dataxchange.gml
# Uninett2010.gml
# Oteglobe.gml
# Sago.gml
# TLex.gml
# Uunet.gml
# Basnet.gml
# Peer1.gml
# NetworkUsa.gml
# Garr201101.gml
# HiberniaCanada.gml
# Restena.gml
# Garr201102.gml
# Globalcenter.gml
# Pacificwave.gml
# GtsPoland.gml
# Belnet2003.gml
# Bellsouth.gml
# Nextgen.gml
# Goodnet.gml
# Dfn.gml
# HiberniaGlobal.gml
# VisionNet.gml
# Belnet2008.gml
# Deltacom.gml
# Rediris.gml
# WideJpn.gml
# Garr201001.gml
# Highwinds.gml
# Cesnet1997.gml
# EliBackbone.gml
# Iris.gml
# Garr201108.gml
# HiberniaNireland.gml
# BeyondTheNetwork.gml
# Quest.gml
# Belnet2005.gml
# Intranetwork.gml
# Nordu2005.gml
# Nsfnet.gml
# Cesnet200706.gml
# Spiralight.gml
# Napnet.gml
# Ans.gml
# HiberniaIreland.gml
# Forthnet.gml
# Netrail.gml
# Mren.gml
# Canerie.gml

# %%
data
# Out:
# [['Bandcon.gml', 22, 28],
#  ['Garr201105.gml', 59, 84],
#  ['VtlWavenet2011.gml', 92, 96],
#  ['Belnet2010.gml', 22, 32],
#  ['Shentel.gml', 28, 35],
#  ['Easynet.gml', 19, 29],
#  ['Arpanet19719.gml', 18, 22],
#  ['Padi.gml', 15, 6],
#  ['Cudi.gml', 51, 52],
#  ['KentmanApr2007.gml', 23, 24],
#  ['Cernet.gml', 41, 59],
#  ['Cogentco.gml', 197, 245],
#  ['Garr199905.gml', 23, 25],
#  ['LambdaNet.gml', 42, 46],
#  ['GtsRomania.gml', 21, 24],
#  ['Airtel.gml', 16, 37],
#  ['Navigata.gml', 13, 17],
#  ['Geant2010.gml', 37, 58],
#  ['Renam.gml', 5, 4],
#  ['Marwan.gml', 16, 18],
#  ['Chinanet.gml', 42, 66],
#  ['Zamren.gml', 36, 34],
#  ['Twaren.gml', 20, 20],
#  ['Integra.gml', 27, 36],
#  ['Cesnet1999.gml', 13, 12],
#  ['CrlNetworkServices.gml', 33, 38],
#  ['Garr200109.gml', 22, 24],
#  ['Cesnet200304.gml', 29, 33],
#  ['Nordu2010.gml', 18, 17],
#  ['Esnet.gml', 68, 92],
#  ['Compuserve.gml', 14, 17],
#  ['Rhnet.gml', 16, 18],
#  ['Garr201008.gml', 55, 74],
#  ['Getnet.gml', 7, 8],
#  ['Garr200212.gml', 27, 29],
#  ['DeutscheTelekom.gml', 39, 62],
#  ['Ernet.gml', 30, 32],
#  ['Kreonet.gml', 13, 12],
#  ['Garr201005.gml', 55, 72],
#  ['HiberniaUs.gml', 22, 29],
#  ['KentmanFeb2008.gml', 26, 28],
#  ['Istar.gml', 23, 23],
#  ['Azrena.gml', 22, 25],
#  ['Cesnet201006.gml', 52, 63],
#  ['Ulaknet.gml', 82, 82],
#  ['KentmanJan2011.gml', 38, 39],
#  ['Arn.gml', 30, 29],
#  ['Ai3.gml', 10, 9],
#  ['BtLatinAmerica.gml', 51, 50],
#  ['Vinaren.gml', 25, 26],
#  ['Switch.gml', 74, 92],
#  ['Pern.gml', 127, 129],
#  ['Abilene.gml', 11, 14],
#  ['GtsHungary.gml', 30, 31],
#  ['Renater2010.gml', 43, 56],
#  ['Harnet.gml', 21, 25],
#  ['Garr201112.gml', 61, 89],
#  ['Kdl.gml', 754, 899],
#  ['Garr201109.gml', 59, 86],
#  ['Garr201111.gml', 60, 87],
#  ['Nordu1997.gml', 14, 13],
#  ['PionierL3.gml', 38, 52],
#  ['Grnet.gml', 37, 47],
#  ['Ntelos.gml', 48, 61],
#  ['Claranet.gml', 15, 18],
#  ['Packetexchange.gml', 21, 27],
#  ['Reuna.gml', 37, 36],
#  ['Renater2008.gml', 33, 43],
#  ['GtsSlovakia.gml', 35, 37],
#  ['Janetlense.gml', 20, 40],
#  ['Globenet.gml', 67, 113],
#  ['Garr201103.gml', 58, 81],
#  ['Xspedius.gml', 34, 49],
#  ['Ibm.gml', 18, 24],
#  ['BtEurope.gml', 24, 37],
#  ['Ion.gml', 125, 150],
#  ['Tinet.gml', 53, 89],
#  ['Latnet.gml', 69, 74],
#  ['Renater2001.gml', 24, 27],
#  ['Garr201110.gml', 59, 87],
#  ['Garr201007.gml', 55, 74],
#  ['Bellcanada.gml', 48, 65],
#  ['Agis.gml', 25, 30],
#  ['IowaStatewideFiberMap.gml', 33, 41],
#  ['Garr200404.gml', 22, 24],
#  ['Oxford.gml', 20, 26],
#  ['Belnet2004.gml', 23, 43],
#  ['Itnet.gml', 11, 10],
#  ['Garr201201.gml', 61, 89],
#  ['Intellifiber.gml', 73, 97],
#  ['Jgn2Plus.gml', 18, 17],
#  ['Cynet.gml', 30, 29],
#  ['UniC.gml', 25, 29],
#  ['Aarnet.gml', 19, 24],
#  ['Eenet.gml', 13, 16],
#  ['Sprint.gml', 11, 18],
#  ['Sunet.gml', 26, 49],
#  ['Sanren.gml', 7, 7],
#  ['Bren.gml', 37, 38],
#  ['Atmnet.gml', 21, 22],
#  ['Roedunet.gml', 42, 50],
#  ['Geant2001.gml', 27, 38],
#  ['Ilan.gml', 14, 15],
#  ['Epoch.gml', 6, 7],
#  ['SwitchL3.gml', 42, 63],
#  ['Digex.gml', 31, 38],
#  ['Garr201004.gml', 54, 71],
#  ['Garr201012.gml', 56, 75],
#  ['Karen.gml', 25, 30],
#  ['Iinet.gml', 31, 35],
#  ['BtNorthAmerica.gml', 36, 76],
#  ['Telecomserbia.gml', 6, 6],
#  ['Heanet.gml', 7, 13],
#  ['Niif.gml', 36, 41],
#  ['Renater1999.gml', 24, 23],
#  ['TataNld.gml', 145, 194],
#  ['Sinet.gml', 74, 76],
#  ['Cesnet200511.gml', 39, 44],
#  ['UsSignal.gml', 63, 79],
#  ['Garr199901.gml', 16, 18],
#  ['Gblnet.gml', 8, 7],
#  ['Myren.gml', 37, 40],
#  ['Geant2009.gml', 34, 52],
#  ['Xeex.gml', 24, 34],
#  ['York.gml', 23, 24],
#  ['Garr200908.gml', 54, 68],
#  ['Interoute.gml', 110, 158],
#  ['Litnet.gml', 43, 43],
#  ['Syringa.gml', 74, 74],
#  ['DialtelecomCz.gml', 193, 151],
#  ['Cesnet2001.gml', 23, 23],
#  ['HurricaneElectric.gml', 24, 37],
#  ['Eunetworks.gml', 15, 19],
#  ['Garr199904.gml', 23, 25],
#  ['Abvt.gml', 23, 31],
#  ['Nsfcnet.gml', 10, 10],
#  ['Garr200909.gml', 55, 69],
#  ['KentmanJul2005.gml', 16, 17],
#  ['Belnet2006.gml', 23, 44],
#  ['HiberniaUk.gml', 15, 15],
#  ['Arpanet19723.gml', 25, 28],
#  ['KentmanAug2005.gml', 28, 29],
#  ['Telcove.gml', 73, 70],
#  ['Bics.gml', 33, 48],
#  ['RoedunetFibre.gml', 48, 52],
#  ['Iij.gml', 37, 66],
#  ['Belnet2009.gml', 21, 31],
#  ['Palmetto.gml', 45, 70],
#  ['Carnet.gml', 44, 43],
#  ['RedBestel.gml', 84, 101],
#  ['Gridnet.gml', 9, 20],
#  ['Garr201010.gml', 56, 75],
#  ['Uran.gml', 24, 24],
#  ['GtsCzechRepublic.gml', 32, 33],
#  ['HostwayInternational.gml', 16, 21],
#  ['Missouri.gml', 67, 83],
#  ['Biznet.gml', 29, 33],
#  ['VtlWavenet2008.gml', 88, 92],
#  ['Janetbackbone.gml', 29, 45],
#  ['PionierL1.gml', 36, 41],
#  ['Garr200902.gml', 54, 71],
#  ['Funet.gml', 26, 31],
#  ['Layer42.gml', 6, 7],
#  ['BsonetEurope.gml', 18, 24],
#  ['Belnet2007.gml', 21, 31],
#  ['Garr201003.gml', 54, 71],
#  ['Surfnet.gml', 50, 73],
#  ['AttMpls.gml', 25, 57],
#  ['Garr201107.gml', 59, 85],
#  ['Gambia.gml', 28, 28],
#  ['Rnp.gml', 31, 34],
#  ['Noel.gml', 19, 25],
#  ['Psinet.gml', 24, 25],
#  ['Internode.gml', 66, 78],
#  ['Savvis.gml', 19, 20],
#  ['Columbus.gml', 70, 85],
#  ['Arpanet19706.gml', 9, 10],
#  ['Fatman.gml', 17, 21],
#  ['Fccn.gml', 23, 27],
#  ['Marnet.gml', 20, 27],
#  ['Renater2004.gml', 30, 36],
#  ['Nordu1989.gml', 7, 6],
#  ['Garr200112.gml', 24, 26],
#  ['Internetmci.gml', 19, 45],
#  ['Renater2006.gml', 33, 43],
#  ['Bbnplanet.gml', 27, 28],
#  ['AsnetAm.gml', 65, 79],
#  ['Arpanet196912.gml', 4, 4],
#  ['Sanet.gml', 43, 45],
#  ['Cesnet1993.gml', 10, 9],
#  ['Evolink.gml', 37, 45],
#  ['Darkstrand.gml', 28, 31],
#  ['Singaren.gml', 11, 10],
#  ['Garr200912.gml', 54, 68],
#  ['Aconet.gml', 23, 31],
#  ['Uninet.gml', 13, 25],
#  ['JanetExternal.gml', 12, 10],
#  ['Garr201104.gml', 59, 83],
#  ['Geant2012.gml', 40, 61],
#  ['Arnes.gml', 34, 47],
#  ['Colt.gml', 153, 191],
#  ['UsCarrier.gml', 158, 189],
#  ['Grena.gml', 16, 15],
#  ['Ntt.gml', 47, 216],
#  ['GtsCe.gml', 149, 193],
#  ['Arpanet19728.gml', 29, 32],
#  ['Amres.gml', 25, 24],
#  ['Uninett2011.gml', 69, 98],
#  ['Cwix.gml', 36, 41],
#  ['Cesnet200603.gml', 39, 44],
#  ['Tw.gml', 76, 118],
#  ['BtAsiaPac.gml', 20, 31],
#  ['Dataxchange.gml', 6, 11],
#  ['Uninett2010.gml', 74, 101],
#  ['Oteglobe.gml', 93, 106],
#  ['Sago.gml', 18, 17],
#  ['TLex.gml', 12, 16],
#  ['Uunet.gml', 49, 84],
#  ['Basnet.gml', 7, 6],
#  ['Peer1.gml', 16, 20],
#  ['NetworkUsa.gml', 35, 39],
#  ['Garr201101.gml', 56, 76],
#  ['HiberniaCanada.gml', 13, 14],
#  ['Restena.gml', 19, 21],
#  ['Garr201102.gml', 57, 77],
#  ['Globalcenter.gml', 9, 36],
#  ['Pacificwave.gml', 18, 27],
#  ['GtsPoland.gml', 33, 37],
#  ['Belnet2003.gml', 23, 43],
#  ['Bellsouth.gml', 51, 66],
#  ['Nextgen.gml', 17, 20],
#  ['Goodnet.gml', 17, 31],
#  ['Dfn.gml', 58, 87],
#  ['HiberniaGlobal.gml', 55, 81],
#  ['VisionNet.gml', 24, 23],
#  ['Belnet2008.gml', 21, 31],
#  ['Deltacom.gml', 113, 183],
#  ['Rediris.gml', 19, 32],
#  ['WideJpn.gml', 30, 33],
#  ['Garr201001.gml', 54, 68],
#  ['Highwinds.gml', 18, 53],
#  ['Cesnet1997.gml', 13, 12],
#  ['EliBackbone.gml', 20, 30],
#  ['Iris.gml', 51, 64],
#  ['Garr201108.gml', 59, 85],
#  ['HiberniaNireland.gml', 18, 22],
#  ['BeyondTheNetwork.gml', 53, 65],
#  ['Quest.gml', 20, 31],
#  ['Belnet2005.gml', 23, 44],
#  ['Intranetwork.gml', 39, 53],
#  ['Nordu2005.gml', 9, 10],
#  ['Nsfnet.gml', 13, 15],
#  ['Cesnet200706.gml', 44, 51],
#  ['Spiralight.gml', 15, 16],
#  ['Napnet.gml', 6, 7],
#  ['Ans.gml', 18, 25],
#  ['HiberniaIreland.gml', 8, 8],
#  ['Forthnet.gml', 62, 62],
#  ['Netrail.gml', 7, 10],
#  ['Mren.gml', 6, 5],
#  ['Canerie.gml', 32, 41]]

# %%
df = pd.DataFrame(data, columns = ['Name', 'Nodes number', 'Edges number'])
df.sort_values(by=['Nodes number'])
# Out:
#                   Name  Nodes number  Edges number
# 187  Arpanet196912.gml             4             4
# 18           Renam.gml             5             4
# 212    Dataxchange.gml             6            11
# 162        Layer42.gml             6             7
# 103          Epoch.gml             6             7
# ..                 ...           ...           ...
# 200           Colt.gml           153           191
# 201      UsCarrier.gml           158           189
# 129  DialtelecomCz.gml           193           151
# 11        Cogentco.gml           197           245
# 57             Kdl.gml           754           899
#
# [261 rows x 3 columns]

# %%
H1=nx.read_graphml('gml_topo/Bren.graphml')
H = nx.Graph(H1)
H

# %%
len(H.nodes())
# Out:
# 37

# %%
len(H.edges())
# Out:
# 38

# %%
for e in H.edges():
    data = H.get_edge_data(e[1], e[0])
    speeds = ['100Mb/s', '200Mb/s', '300Mb/s']
    H[e[1]][e[0]]["LinkLabel"] = random.choice(speeds)
    print(H[e[1]][e[0]])
#     print(data)
# Out:
# {'LinkType': 'Ethernet', 'LinkLabel': '300Mb/s', 'key': 0}
# {'LinkType': 'Ethernet', 'LinkLabel': '200Mb/s', 'key': 0}
# {'LinkSpeed': '1', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0}
# {'LinkSpeed': '100', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'M', 'LinkSpeedRaw': 100000000.0, 'key': 0}
# {'LinkSpeed': '1', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0}
# {'LinkSpeed': '100', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'M', 'LinkSpeedRaw': 100000000.0, 'key': 0}
# {'LinkType': 'Ethernet', 'LinkLabel': '100Mb/s', 'key': 0}
# {'LinkType': 'Ethernet', 'LinkLabel': '300Mb/s', 'key': 0}
# {'LinkType': 'Ethernet', 'LinkSpeed': '1', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0}
# {'LinkSpeed': '100', 'LinkLabel': '200Mb/s', 'LinkSpeedUnits': 'M', 'LinkSpeedRaw': 100000000.0, 'key': 0}
# {'LinkSpeed': '1', 'LinkLabel': '200Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0}
# {'LinkType': 'Ethernet', 'LinkSpeed': '1', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0}
# {'LinkType': 'Ethernet', 'LinkLabel': '100Mb/s', 'key': 0}
# {'LinkType': 'Ethernet', 'LinkLabel': '300Mb/s', 'key': 0}
# {'LinkSpeed': '100', 'LinkLabel': '200Mb/s', 'LinkSpeedUnits': 'M', 'LinkSpeedRaw': 100000000.0, 'key': 0}
# {'LinkSpeed': '100', 'LinkLabel': '200Mb/s', 'LinkSpeedUnits': 'M', 'LinkSpeedRaw': 100000000.0, 'key': 0}
# {'LinkSpeed': '1', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0}
# {'LinkSpeed': '1', 'LinkLabel': '100Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0}
# {'LinkSpeed': '1', 'LinkLabel': '200Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0}
# {'LinkSpeed': '1', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0}
# {'LinkSpeed': '1', 'LinkLabel': '100Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0}
# {'LinkSpeed': '1', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0}
# {'LinkSpeed': '100', 'LinkLabel': '200Mb/s', 'LinkSpeedUnits': 'M', 'LinkSpeedRaw': 100000000.0, 'key': 0}
# {'LinkSpeed': '1', 'LinkLabel': '200Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0}
# {'LinkSpeed': '100', 'LinkLabel': '200Mb/s', 'LinkSpeedUnits': 'M', 'LinkSpeedRaw': 100000000.0, 'key': 0}
# {'LinkSpeed': '1', 'LinkLabel': '100Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0}
# {'LinkSpeed': '1', 'LinkLabel': '100Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0}
# {'LinkSpeed': '1', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0}
# {'LinkSpeed': '100', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'M', 'LinkSpeedRaw': 100000000.0, 'key': 0}
# {'LinkSpeed': '1', 'LinkLabel': '200Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0}
# {'LinkSpeed': '1', 'LinkLabel': '100Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0}
# {'LinkType': 'Ethernet', 'LinkLabel': '100Mb/s', 'key': 0}
# {'LinkType': 'Ethernet', 'LinkLabel': '200Mb/s', 'key': 0}
# {'LinkType': 'Ethernet', 'LinkLabel': '200Mb/s', 'key': 0}
# {'LinkType': 'Ethernet', 'LinkLabel': '300Mb/s', 'key': 0}
# {'LinkType': 'Ethernet', 'LinkLabel': '200Mb/s', 'key': 0}
# {'LinkType': 'Ethernet', 'LinkLabel': '300Mb/s', 'key': 0}
# {'LinkType': 'Ethernet', 'LinkLabel': '300Mb/s', 'key': 0}

# %%
# Base for measure is Mb/s
mmnt = {'b/s':1e-6, 'kb/s': 1e-3, 'Mb/s': 1, 'Gb/s':1e+3, 'Tb/s':1e+6}

# %%
def unit_measure(strr):
    strr = strr.replace(" ", "")
    i = strr.rfind('b/s') + 3
    strr = strr[:i]
    for m in mmnt.keys():
        if m in strr:
            pattern = '{:d}' + m
            k = parse(pattern, strr)
            if k != None:
                return k[0]*mmnt[m]
    return None

# %%
bflows = {}
for e in H.edges():
    data = H.get_edge_data(e[1], e[0])
    if data['LinkLabel'] != 'Ethernet':
        speed = data['LinkLabel']
    else:
        speed = "100Mb/s"
        data['LinkLabel'] = speed
    bandwidth = unit_measure(speed)
    step = bandwidth / 100.0
    back_flow = random.randrange(0.0, bandwidth, step)
    bflows[e] = {'BackgroundFlow': back_flow}
        
nx.set_edge_attributes(H, bflows)
# print("New data in network")
# print(H.edges(data = True))

# %%
bflows
# Out:
# {('0', '3'): {'BackgroundFlow': 135},
#  ('0', '28'): {'BackgroundFlow': 2},
#  ('1', '3'): {'BackgroundFlow': 126},
#  ('1', '4'): {'BackgroundFlow': 96},
#  ('1', '6'): {'BackgroundFlow': 264},
#  ('1', '7'): {'BackgroundFlow': 264},
#  ('2', '34'): {'BackgroundFlow': 30},
#  ('2', '3'): {'BackgroundFlow': 42},
#  ('3', '8'): {'BackgroundFlow': 294},
#  ('3', '14'): {'BackgroundFlow': 18},
#  ('3', '21'): {'BackgroundFlow': 120},
#  ('3', '22'): {'BackgroundFlow': 237},
#  ('3', '29'): {'BackgroundFlow': 90},
#  ('3', '30'): {'BackgroundFlow': 96},
#  ('5', '14'): {'BackgroundFlow': 140},
#  ('9', '15'): {'BackgroundFlow': 162},
#  ('10', '16'): {'BackgroundFlow': 27},
#  ('10', '17'): {'BackgroundFlow': 69},
#  ('10', '11'): {'BackgroundFlow': 88},
#  ('11', '12'): {'BackgroundFlow': 168},
#  ('11', '13'): {'BackgroundFlow': 1},
#  ('11', '21'): {'BackgroundFlow': 162},
#  ('15', '22'): {'BackgroundFlow': 56},
#  ('17', '25'): {'BackgroundFlow': 194},
#  ('18', '23'): {'BackgroundFlow': 88},
#  ('19', '21'): {'BackgroundFlow': 12},
#  ('20', '21'): {'BackgroundFlow': 21},
#  ('22', '25'): {'BackgroundFlow': 48},
#  ('23', '25'): {'BackgroundFlow': 36},
#  ('24', '25'): {'BackgroundFlow': 106},
#  ('25', '26'): {'BackgroundFlow': 16},
#  ('27', '35'): {'BackgroundFlow': 35},
#  ('27', '28'): {'BackgroundFlow': 146},
#  ('31', '34'): {'BackgroundFlow': 156},
#  ('32', '34'): {'BackgroundFlow': 27},
#  ('33', '34'): {'BackgroundFlow': 102},
#  ('34', '35'): {'BackgroundFlow': 288},
#  ('35', '36'): {'BackgroundFlow': 240}}

# %%
for e in H.edges():
    print(H[e[1]][e[0]])
# Out:
# {'LinkType': 'Ethernet', 'LinkLabel': '300Mb/s', 'key': 0, 'BackgroundFlow': 135}
# {'LinkType': 'Ethernet', 'LinkLabel': '200Mb/s', 'key': 0, 'BackgroundFlow': 2}
# {'LinkSpeed': '1', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0, 'BackgroundFlow': 126}
# {'LinkSpeed': '100', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'M', 'LinkSpeedRaw': 100000000.0, 'key': 0, 'BackgroundFlow': 96}
# {'LinkSpeed': '1', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0, 'BackgroundFlow': 264}
# {'LinkSpeed': '100', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'M', 'LinkSpeedRaw': 100000000.0, 'key': 0, 'BackgroundFlow': 264}
# {'LinkType': 'Ethernet', 'LinkLabel': '100Mb/s', 'key': 0, 'BackgroundFlow': 30}
# {'LinkType': 'Ethernet', 'LinkLabel': '300Mb/s', 'key': 0, 'BackgroundFlow': 42}
# {'LinkType': 'Ethernet', 'LinkSpeed': '1', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0, 'BackgroundFlow': 294}
# {'LinkSpeed': '100', 'LinkLabel': '200Mb/s', 'LinkSpeedUnits': 'M', 'LinkSpeedRaw': 100000000.0, 'key': 0, 'BackgroundFlow': 18}
# {'LinkSpeed': '1', 'LinkLabel': '200Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0, 'BackgroundFlow': 120}
# {'LinkType': 'Ethernet', 'LinkSpeed': '1', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0, 'BackgroundFlow': 237}
# {'LinkType': 'Ethernet', 'LinkLabel': '100Mb/s', 'key': 0, 'BackgroundFlow': 90}
# {'LinkType': 'Ethernet', 'LinkLabel': '300Mb/s', 'key': 0, 'BackgroundFlow': 96}
# {'LinkSpeed': '100', 'LinkLabel': '200Mb/s', 'LinkSpeedUnits': 'M', 'LinkSpeedRaw': 100000000.0, 'key': 0, 'BackgroundFlow': 140}
# {'LinkSpeed': '100', 'LinkLabel': '200Mb/s', 'LinkSpeedUnits': 'M', 'LinkSpeedRaw': 100000000.0, 'key': 0, 'BackgroundFlow': 162}
# {'LinkSpeed': '1', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0, 'BackgroundFlow': 27}
# {'LinkSpeed': '1', 'LinkLabel': '100Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0, 'BackgroundFlow': 69}
# {'LinkSpeed': '1', 'LinkLabel': '200Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0, 'BackgroundFlow': 88}
# {'LinkSpeed': '1', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0, 'BackgroundFlow': 168}
# {'LinkSpeed': '1', 'LinkLabel': '100Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0, 'BackgroundFlow': 1}
# {'LinkSpeed': '1', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0, 'BackgroundFlow': 162}
# {'LinkSpeed': '100', 'LinkLabel': '200Mb/s', 'LinkSpeedUnits': 'M', 'LinkSpeedRaw': 100000000.0, 'key': 0, 'BackgroundFlow': 56}
# {'LinkSpeed': '1', 'LinkLabel': '200Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0, 'BackgroundFlow': 194}
# {'LinkSpeed': '100', 'LinkLabel': '200Mb/s', 'LinkSpeedUnits': 'M', 'LinkSpeedRaw': 100000000.0, 'key': 0, 'BackgroundFlow': 88}
# {'LinkSpeed': '1', 'LinkLabel': '100Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0, 'BackgroundFlow': 12}
# {'LinkSpeed': '1', 'LinkLabel': '100Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0, 'BackgroundFlow': 21}
# {'LinkSpeed': '1', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0, 'BackgroundFlow': 48}
# {'LinkSpeed': '100', 'LinkLabel': '300Mb/s', 'LinkSpeedUnits': 'M', 'LinkSpeedRaw': 100000000.0, 'key': 0, 'BackgroundFlow': 36}
# {'LinkSpeed': '1', 'LinkLabel': '200Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0, 'BackgroundFlow': 106}
# {'LinkSpeed': '1', 'LinkLabel': '100Mb/s', 'LinkSpeedUnits': 'G', 'LinkSpeedRaw': 1000000000.0, 'key': 0, 'BackgroundFlow': 16}
# {'LinkType': 'Ethernet', 'LinkLabel': '100Mb/s', 'key': 0, 'BackgroundFlow': 35}
# {'LinkType': 'Ethernet', 'LinkLabel': '200Mb/s', 'key': 0, 'BackgroundFlow': 146}
# {'LinkType': 'Ethernet', 'LinkLabel': '200Mb/s', 'key': 0, 'BackgroundFlow': 156}
# {'LinkType': 'Ethernet', 'LinkLabel': '300Mb/s', 'key': 0, 'BackgroundFlow': 27}
# {'LinkType': 'Ethernet', 'LinkLabel': '200Mb/s', 'key': 0, 'BackgroundFlow': 102}
# {'LinkType': 'Ethernet', 'LinkLabel': '300Mb/s', 'key': 0, 'BackgroundFlow': 288}
# {'LinkType': 'Ethernet', 'LinkLabel': '300Mb/s', 'key': 0, 'BackgroundFlow': 240}

# %%
nx.write_graphml(H, 'change_topo/cBren.graphml')

# %%
def print_Graph(H):
    nodes = []
    for node in H.nodes():
        nodes.append({'id': node, 'label': node})
    edges = []
    for edge in H.edges():
        data = H.get_edge_data(edge[0], edge[1])
        perc = data['BackgroundFlow'] / unit_measure(data['LinkLabel'])
        color = 'GREEN'
        if perc <= 0.5:
            color = 'GREEN'
        elif perc <= 0.8:
            color = 'YELLOW'
        elif perc <= 1:
            color = 'RED'
        edges.append({'from': edge[1], 'to': edge[0], 
                      'dashes':False, 'label': (str)(unit_measure(data['LinkLabel'])) + 'Mb/s', 
                      'font':{'align': 'top'},
                      'color': color,
                      'width': 4})
#         else:
#             edges.append({'from': edge[1], 'to': edge[0],
#                           'dashes':True, 'label': '0Mb/s', 
#                           'font':{'align': 'top'},
#                           'color': 'BLACK'})
    return (nodes, edges)

# %%
nodes, edges = print_Graph(H)

# %%
# Transform the graph into a JSON graph
data = {"nodes":nodes, "edges":edges}
jsonGraph = json.dumps(data, indent=4)

# Send to Javascript
Javascript("""window.jsonGraph={};""".format(jsonGraph))

# %%
# %%javascript
# requirejs.config({
#     paths: {
#         vis: 'vis'
#     }
# });
#
# require(['vis'], function(vis){
#
#     // create a network
#     var container = document.getElementById('mynetwork');
#
#     var options = {
#         width: '900px',
#         height: '500px',
#         edges:{
#           shadow: true,
#           smooth: true,
#           background:{
#             enabled: true,
#             color: '#ff0000'
#           }
#         }
#     }
#
#     // We load the JSON graph we generated from iPython input
#     var graph = window.jsonGraph;
#
#     // Display Graph
#     var network = new vis.Network(container, graph, options);
# });

# %%
# %%html
# <div id="mynetwork"></div>
# Out:
# <div id="mynetwork"></div>
